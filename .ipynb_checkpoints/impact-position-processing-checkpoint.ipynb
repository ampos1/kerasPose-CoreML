# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("impact.txt")

# %%
df = pd.DataFrame(data)

# %%
df.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)

# %%
for i in range(0,df['values'].count()):
    if type(df['values'][i]) != str:
        val = df['values'][i]
        df['values'][i] = df['values'][i].to_string()

# %%
for i in range(0,df['values'].count()):
    if 'real' in df['values'][i]:
        temp = re.search('>(.*)</',df['values'][i])
        df['values'][i] = temp.group(1)

# %%
temp_df = df

# %%
check = ['a','e','i','o','u'] 

for i in range(0,temp_df['values'].count()):
    for vowel in check:
        if vowel in list(temp_df['values'][i]):
            temp_df.drop(index = i,inplace = True)
            break

# %%
res = temp_df
res = res.reset_index()
res.drop('index',axis=1,inplace=True)

# %%
x_temp = pd.DataFrame(np.zeros((4368,1)))
y_temp = pd.DataFrame(np.zeros((4368,1)))
z_temp = pd.DataFrame(np.zeros((4368,1)))

# %%
for i in range(0,int(res.count()),3):
    if(i == 0):
        x_temp[0][i ] = res['values'][i]
    else:
        x_temp[0][0+(i/3)] = res['values'][i]

# %%
def extract_x_values(data, x_vals):
    for i in range(0,int(data.count()),3):
        if(i == 0):
            x_vals[0][i ] = data['values'][i]
        else:
            x_vals[0][(i/3)] = data['values'][i]
    return x_vals

# %%
def extract_y_values(data, y_vals):
    for i in range(1,int(data.count()),3):
        if(i == 1):
            y_vals[0][i-1] = data['values'][i]
        else:
            y_vals[0][int((i/3))] = data['values'][i]
    return y_vals

# %%
def extract_z_values(data,z_vals):
    for i in range(2,int(data.count()),3):
        if(i == 2):
            z_vals[0][i-2] = data['values'][i]
        else:
            z_vals[0][(i-2)/3] = data['values'][i]
    return z_vals

# %%
x_temp = extract_x_values(res,x_temp)
y_temp = extract_y_values(res,y_temp)
z_temp = extract_z_values(res,z_temp)

# %%
x_temp.rename(columns={0:'x'},inplace=True)
y_temp.rename(columns={0:'y'},inplace=True)
z_temp.rename(columns={0:'z'},inplace=True)

# %%
xyz_df = pd.concat([x_temp,y_temp,z_temp],axis=1)

# %%
def restructure(data):
    organized_df = pd.DataFrame()
    for i in range(0,273):
        lower_bound = 0
        upper_bound = 15
        curr_lower = lower_bound + (i*16)
        curr_upper = upper_bound + (i*16)
        
        df_splice = data.loc[curr_lower:curr_upper,:]
        df_splice.reset_index(inplace=True,drop=True)
        df_splice = df_splice.transpose()
        organized_df = pd.concat([organized_df,df_splice])
    
    return organized_df

# %%
xyz_df = restructure(xyz_df)
xyz_df
# Out:
#             0           1           2           3           4           5   \
# x   222.500000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.388186  -65.725182 -638.184204 -458.454895   32.588058 -437.712067
# x   227.500000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.286297  -69.765022 -640.088562 -460.621033   37.020493 -440.530975
# x   229.166672  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.249388  -71.114189 -640.801880 -461.300415   38.493408 -441.487335
# x   230.000000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.231587  -71.786186 -641.234253 -461.642029   39.226669 -441.900238
# x   230.500000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.221638  -72.179512 -641.560242 -461.863220   39.654175 -442.105316
# x   230.833328  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.215023  -72.441414 -641.777588 -462.010742   39.939072 -442.242950
# x   231.071426  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.210290  -72.628601 -641.932251 -462.116211   40.142746 -442.340302
# x   231.250000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2.206733  -72.769371 -642.049072 -462.195862   40.295502 -442.414093
# x   232.500000  222.500000  222.500000  222.500000  282.500000  262.500000
# y    96.666664  376.666656  483.333344  616.666687  376.666656  483.333344
# z    -2