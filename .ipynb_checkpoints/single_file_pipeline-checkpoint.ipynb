# %%
import pandas as pd
import numpy as np
import re

# %%
address_data = pd.read_csv("address_c.txt")
impact_data = pd.read_csv("impact_c.txt")
finish_data = pd.read_csv("Finish_c.txt")
backswing_data = pd.read_csv("backswing_c.txt")

# %%
df_address = pd.DataFrame(address_data)
df_impact = pd.DataFrame(impact_data)
df_finish = pd.DataFrame(finish_data)
df_backswing = pd.DataFrame(backswing_data)

# %%
df_address.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)
df_impact.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)
df_finish.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)
df_backswing.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)

# %%
def data_processing(df):
    
    check = ['a','e','i','o','u'] 
    
    for i in range(0,df['values'].count()):
        
        if type(df['values'][i]) != str:
            val = df['values'][i]
            df['values'][i] = df['values'][i].to_string()

        if 'real' in df['values'][i]:
            temp = re.search('>(.*)</',df['values'][i])
            df['values'][i] = temp.group(1)
    
        for vowel in check:
            if vowel in list(df['values'][i]):
                df.drop(index = i,inplace = True)
                break
            
    return df

# %%
df_address_1 = data_processing(df_address)
df_impact_1 = data_processing(df_impact)
df_finish_1 = data_processing(df_finish)
df_backswing_1 = data_processing(df_backswing)

# %%
def update_index(df):
    df = df.reset_index()
    df.drop('index',axis=1,inplace=True)
    return df

# %%
df_address_1 = update_index(df_address_1)
df_impact_1 = update_index(df_impact_1)
df_finish_1 = update_index(df_finish_1)
df_backswing_1 = update_index(df_backswing_1)

# %%
x_temp = pd.DataFrame(np.zeros((4368,1)))
y_temp = pd.DataFrame(np.zeros((4368,1)))
z_temp = pd.DataFrame(np.zeros((4368,1)))
c_temp = pd.DataFrame(np.zeros((4368,1)))

# %%
def extract_x_values(data, x_vals):
    for i in range(0,int(data.count()),4):
        if(i == 0):
            x_vals[0][i] = data['values'][i]
        else:
            x_vals[0][(i/4)] = data['values'][i]
    return x_vals

# %%
def extract_y_values(data, y_vals):
    for i in range(1,int(data.count()),4):
        if(i == 1):
            y_vals[0][i-1] = data['values'][i]
        else:
            y_vals[0][(i-1)/4] = data['values'][i]
    return y_vals

# %%
def extract_z_values(data,z_vals):
    for i in range(2,int(data.count()),4):
        if(i == 2):
            z_vals[0][i-2] = data['values'][i]
        else:
            z_vals[0][(i-2)/4] = data['values'][i]
    return z_vals

# %%
def extract_c_values(data,c_vals):
    for i in range(3,int(data.count()),4):
        if(i == 3):
            c_vals[0][i-3] = data['values'][i]
        else:
            c_vals[0][int((i-3)/4)] = data['values'][i]
    return c_vals

# %%
address_x_temp = extract_x_values(df_address_1,x_temp).rename(columns={0:'x'})
address_y_temp = extract_y_values(df_address_1,y_temp).rename(columns={0:'y'})
address_z_temp = extract_z_values(df_address_1,z_temp).rename(columns={0:'z'})
address_c_temp = extract_c_values(df_address_1,c_temp).rename(columns={0:'c'})

impact_x_temp = extract_x_values(df_impact_1,x_temp).rename(columns={0:'x'})
impact_y_temp = extract_y_values(df_impact_1,y_temp).rename(columns={0:'y'})
impact_z_temp = extract_z_values(df_impact_1,z_temp).rename(columns={0:'z'})
impact_c_temp = extract_c_values(df_impact_1,c_temp).rename(columns={0:'c'})

finish_x_temp = extract_x_values(df_finish_1,x_temp).rename(columns={0:'x'})
finish_y_temp = extract_y_values(df_finish_1,y_temp).rename(columns={0:'y'})
finish_z_temp = extract_z_values(df_finish_1,z_temp).rename(columns={0:'z'})
finish_c_temp = extract_c_values(df_finish_1,c_temp).rename(columns={0:'c'})

backswing_x_temp = extract_x_values(df_backswing_1,x_temp).rename(columns={0:'x'})
backswing_y_temp = extract_y_values(df_backswing_1,y_temp).rename(columns={0:'y'})
backswing_z_temp = extract_z_values(df_backswing_1,z_temp).rename(columns={0:'z'})
backswing_c_temp = extract_c_values(df_backswing_1,c_temp).rename(columns={0:'c'})

# %%
address_df = pd.concat([address_x_temp,address_y_temp,address_z_temp,address_c_temp],axis=1)
impact_df = pd.concat([impact_x_temp,impact_y_temp,impact_z_temp,impact_c_temp],axis=1)
finish_df = pd.concat([finish_x_temp,finish_y_temp,finish_z_temp,finish_c_temp],axis=1)
backswing_df = pd.concat([backswing_x_temp,backswing_y_temp,backswing_z_temp,backswing_c_temp],axis=1)

# %%
def restructure(data):
    organized_df = pd.DataFrame()
    for i in range(0,273):
        lower_bound = 0
        upper_bound = 15
        curr_lower = lower_bound + (i*16)
        curr_upper = upper_bound + (i*16)
        
        df_splice = data.loc[curr_lower:curr_upper,:]
        df_splice.reset_index(inplace=True,drop=True)
        df_splice = df_splice.transpose()
        organized_df = pd.concat([organized_df,df_splice])
    
    return organized_df

# %%
address_df = restructure(address_df)
impact_df = restructure(impact_df)
finish_df = restructure(finish_df)
backswing_df = restructure(backswing_df)

# %%
address_df
# Out:
#             0           1           2           3           4           5   \
# x   262.500000  202.500000  182.500000  182.500000  202.500000  202.500000
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -0.995418 -129.388245 -530.767944 -352.744324  115.185043 -151.541901
# c     0.132191    0.132191    0.132191    0.132191    0.132191    0.132191
# x   262.500000  202.500000  182.500000  182.500000  202.500000  192.500000
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -1.005334 -126.528633 -533.433044 -353.817017  112.559601 -156.813202
# c     0.131738    0.131738    0.131738    0.131738    0.131738    0.131738
# x   262.500000  202.500000  182.500000  182.500000  202.500000  195.833328
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -1.002035 -127.481659 -532.544922 -353.459961  113.434608 -155.056335
# c     0.131640    0.131640    0.131640    0.131640    0.131640    0.131640
# x   262.500000  202.500000  182.500000  182.500000  202.500000  197.500000
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -1.000376 -127.958397 -532.101196 -353.280823  113.872314 -154.177826
# c     0.131659    0.131659    0.131659    0.131659    0.131659    0.131659
# x   262.500000  202.500000  182.500000  182.500000  202.500000  198.500000
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -0.999394 -128.244263 -531.834290 -353.173828  114.134819 -153.650909
# c     0.131617    0.131617    0.131617    0.131617    0.131617    0.131617
# x   262.500000  202.500000  182.500000  182.500000  202.500000  195.833328
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -1.002035 -127.481659 -532.544922 -353.459961  113.434608 -155.056335
# c     0.131578    0.131578    0.131578    0.131578    0.131578    0.131578
# x   262.500000  202.500000  182.500000  182.500000  202.500000  196.785721
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# z    -1.001089 -127.754066 -532.291443 -353.357300  113.684723 -154.554169
# c     0.131548    0.131548    0.131548    0.131548    0.131548    0.131548
# x   262.500000  202.500000  182.500000  182.500000  202.500000  197.500000
# y    30.000000  190.000000  350.000000  483.333344  216.666672  350.000000
# ..         ...         ...         ...         ...         ...         ...
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073887    0.073887    0.073887    0.073887    0.073887    0.073887
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073897    0.073897    0.073897    0.073897    0.073897    0.073897
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073978    0.073978    0.073978    0.073978    0.073978    0.073978
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.074020    0.074020    0.074020    0.074020    0.074020    0.074020
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.074013    0.074013    0.074013    0.074013    0.074013    0.074013
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073994    0.073994    0.073994    0.073994    0.073994    0.073994
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073982    0.073982    0.073982    0.073982    0.073982    0.073982
# x   242.500000  222.500000  222.500000  282.500000  222.500000  262.500000
# y   283.333344  376.666656  510.000000  590.000000  376.666656  483.333344
# z    -5.185480  -35.974621 -431.675690 -182.210510    7.492224 -314.998260
# c     0.073992    0.073992    0.073992    0.073992    0.073992    0.073992
#
#             6           7           8           9           10          11  \
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -208.365768  127.759636  -34.598038 -439.496735  618.758728  516.504639
# c     0.132191    0.132191    0.132191    0.132191    0.132191    0.132191
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -211.936966  129.582230  -31.753204 -435.931427  623.059875  519.042419
# c     0.131738    0.131738    0.131738    0.131738    0.131738    0.131738
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -210.746506  128.975418  -32.701935 -437.120209  621.625427  518.196655
# c     0.131640    0.131640    0.131640    0.131640    0.131640    0.131640
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -210.152130  128.671738  -33.175964 -437.714874  620.908508  517.773743
# c     0.131659    0.131659    0.131659    0.131659    0.131659    0.131659
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -209.793961  128.489258  -33.460541 -438.071167  620.478516  517.519897
# c     0.131617    0.131617    0.131617    0.131617    0.131617    0.131617
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -210.746506  128.975418  -32.701935 -437.120209  621.625427  518.196655
# c     0.131578    0.131578    0.131578    0.131578    0.131578    0.131578
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# z  -210.406219  128.801971  -32.972992 -437.460175  621.215698  517.954956
# c     0.131548    0.131548    0.131548    0.131548    0.131548    0.131548
# x   202.500000  232.500000  262.500000  282.500000  302.500000  302.500000
# y   483.333344  130.000000   56.666668    3.333333   30.000000   56.666668
# ..         ...         ...         ...         ...         ...         ...
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073887    0.073887    0.073887    0.073887    0.073887    0.073887
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073897    0.073897    0.073897    0.073897    0.073897    0.073897
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073978    0.073978    0.073978    0.073978    0.073978    0.073978
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.074020    0.074020    0.074020    0.074020    0.074020    0.074020
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.074013    0.074013    0.074013    0.074013    0.074013    0.074013
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073994    0.073994    0.073994    0.073994    0.073994    0.073994
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073982    0.073982    0.073982    0.073982    0.073982    0.073982
# x   282.500000  227.500000  232.500000  242.500000  242.500000  242.500000
# y   590.000000  290.000000  203.333328  190.000000  110.000000  190.000000
# z  -258.579468    6.673131  -77.516068 -404.805939  639.830139  427.928925
# c     0.073992    0.073992    0.073992    0.073992    0.073992    0.073992
#
#             12          13          14          15
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   332.707733   21.314322  -70.092361   38.337502
# c     0.132191    0.132191    0.132191    0.132191
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   329.577942   24.658377  -66.561371   39.946938
# c     0.131738    0.131738    0.131738    0.131738
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   330.620544   23.543753  -67.738480   39.410591
# c     0.131640    0.131640    0.131640    0.131640
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   331.142212   22.986685  -68.326797   39.142250
# c     0.131659    0.131659    0.131659    0.131659
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   331.455414   22.652151  -68.680084   38.981331
# c     0.131617    0.131617    0.131617    0.131617
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   330.620544   23.543753  -67.738480   39.410591
# c     0.131578    0.131578    0.131578    0.131578
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# z   330.919006   23.225454  -68.074799   39.257088
# c     0.131548    0.131548    0.131548    0.131548
# x   282.500000  282.500000  222.500000  182.500000
# y    83.333336    3.333333   56.666668   83.333336
# ..         ...         ...         ...         ...
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073887    0.073887    0.073887    0.073887
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073897    0.073897    0.073897    0.073897
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073978    0.073978    0.073978    0.073978
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.074020    0.074020    0.074020    0.074020
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.074013    0.074013    0.074013    0.074013
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073994    0.073994    0.073994    0.073994
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073982    0.073982    0.073982    0.073982
# x   242.500000  282.500000  222.500000  222.500000
# y   296.666656  243.333328  216.666672  296.666656
# z   376.675934   68.222466  -25.992403  117.680458
# c     0.073992    0.073992    0.073992    0.073992
#
# [1092 rows x 16 columns]

# %%
address_df['Address Position'] = np.ones((819,))
backswing_df['Backswing Position'] = np.full((819,)2)
impact_df['Impact Position'] = np.full((819,),3)
finish_df['Finish Position'] = np.full((819,),4)
