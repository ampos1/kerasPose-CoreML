# %%
import pandas as pd
import numpy as np
import re

# %%
input_txt = pd.read_csv("finish.txt")
df = pd.DataFrame(input_txt)
df.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)

# %%
def data_processing(df):
    
    check = ['a','e','i','o','u'] 
    
    for i in range(0,df['values'].count()):
        
        if type(df['values'][i]) != str:
            val = df['values'][i]
            df['values'][i] = df['values'][i].to_string()

        if 'real' in df['values'][i]:
            temp = re.search('>(.*)</',df['values'][i])
            df['values'][i] = temp.group(1)
    
        for vowel in check:
            if vowel in list(df['values'][i]):
                df.drop(index = i,inplace = True)
                break
            
    return df

def update_index(df):
    df = df.reset_index()
    df.drop('index',axis=1,inplace=True)
    return df

# %%
df_processed = data_processing(df)
df_processed = update_index(df_processed)

# %%
def extract_x_values(data):
    temp_arr = pd.DataFrame(np.zeros((int(data.size/4),1)))
    for i in range(0,int(data.count()),4):
        if(i == 0):
            temp_arr[0][i] = data['values'][i]
        else:
            temp_arr[0][(i/4)] = data['values'][i]
    return temp_arr

# %%
def extract_y_values(data):
    temp_arr = pd.DataFrame(np.zeros((int(data.size/4),1)))
    for i in range(1,int(data.count()),4):
        if(i == 1):
            temp_arr[0][i-1] = data['values'][i]
        else:
            temp_arr[0][(i-1)/4] = data['values'][i]
    return temp_arr

# %%
def extract_z_values(data):
    temp_arr = pd.DataFrame(np.zeros((int(data.size/4),1)))
    for i in range(2,int(data.count()),4):
        if(i == 2):
            temp_arr[0][i-2] = data['values'][i]
        else:
            temp_arr[0][(i-2)/4] = data['values'][i]
    return temp_arr

# %%
def extract_c_values(data):
    temp_arr = pd.DataFrame(np.zeros((int(data.size/4),1)))
    for i in range(3,int(data.count()),4):
        if(i == 3):
            temp_arr[0][i-3] = data['values'][i]
        else:
            temp_arr[0][int((i-3)/4)] = data['values'][i]
    return temp_arr

# %%
x_temp = extract_x_values(df_processed).rename(columns={0:'x'})
y_temp = extract_y_values(df_processed).rename(columns={0:'y'})
z_temp = extract_z_values(df_processed).rename(columns={0:'z'})
c_temp = extract_c_values(df_processed).rename(columns={0:'c'})

# %%
xyzc_df = pd.concat([x_temp,y_temp,z_temp,c_temp],axis=1)

# %%
def restructure(data):
    organized_df = pd.DataFrame()
    for i in range(0,int(data.shape[0]/16)):
        lower_bound = 0
        upper_bound = 15
        curr_lower = lower_bound + (i*16)
        curr_upper = upper_bound + (i*16)
        
        df_splice = data.loc[curr_lower:curr_upper,:]
        df_splice.reset_index(inplace=True,drop=True)
        df_splice = df_splice.transpose()
        organized_df = pd.concat([organized_df,df_splice])
    
    return organized_df

# %%
xyzc_df = restructure(xyzc_df)

# %%
xyzc_df
# Out:
#             0           1           2           3           4           5   \
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.365246    0.079187    0.107873    0.111117    0.148952    0.136239
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.363294    0.076159    0.105007    0.108217    0.148035    0.132144
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.361829    0.073690    0.102305    0.106593    0.147568    0.129535
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.362474    0.074492    0.102578    0.105296    0.142146    0.131026
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.360260    0.071228    0.099143    0.104165    0.142626    0.127877
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.358473    0.069293    0.097180    0.103509    0.142420    0.126244
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# z    -3.563773  -71.411919 -436.998566 -141.374084   50.184036  -27.886620
# c     0.357002    0.068227    0.096104    0.103354    0.142498    0.125310
# x   322.500000  262.500000  262.500000  182.500000  282.500000  302.500000
# y   136.666672  323.333344  430.000000  510.000000  350.000000  430.000000
# ..         ...         ...         ...         ...         ...         ...
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.072883    0.055603    0.203543    0.116042    0.242299    0.193658
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.072899    0.055572    0.203388    0.116100    0.242346    0.193720
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.073419    0.055673    0.201640    0.116433    0.242440    0.194155
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.074457    0.057161    0.198984    0.117751    0.244982    0.195535
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.075524    0.058617    0.196649    0.119637    0.247374    0.196827
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.075975    0.059114    0.195190    0.120719    0.249175    0.197491
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.076423    0.059598    0.193711    0.121767    0.250951    0.198156
# x    92.500000   82.500000   82.500000   62.500000  102.500000  102.500000
# y   110.000000  190.000000  270.000000  323.333344  190.000000  270.000000
# z    -2.182027  -34.797543 -247.653442 -130.357269   17.862932 -192.516724
# c     0.076300    0.059644    0.195369    0.123259    0.252895    0.197249
#
#             6           7           8           9           10          11  \
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.059511    0.132520    0.363091    0.563657    0.791287    0.360823
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058310    0.134434    0.365432    0.563116    0.791244    0.364679
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058002    0.135324    0.365433    0.562391    0.791183    0.366434
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058523    0.134925    0.363465    0.561592    0.791441    0.367012
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058274    0.135707    0.361723    0.562939    0.790863    0.367433
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058155    0.136098    0.360169    0.562795    0.790605    0.367255
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# z   160.438553  141.126465    3.003372 -321.268799  839.291138  562.862671
# c     0.058138    0.136218    0.359419    0.562032    0.790652    0.367390
# x   302.500000  342.500000  412.500000  422.500000  422.500000  442.500000
# y   536.666687  223.333328  110.000000   83.333336   56.666668  110.000000
# ..         ...         ...         ...         ...         ...         ...
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.351778    0.169824    0.399385    0.343819    0.160206    0.408775
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.351769    0.169944    0.399382    0.343835    0.160393    0.408593
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.351470    0.170505    0.399489    0.341999    0.160296    0.407498
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.350354    0.170383    0.400502    0.340443    0.159972    0.408974
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.349340    0.169796    0.402083    0.339194    0.159780    0.410979
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.347384    0.167646    0.402761    0.337386    0.159326    0.411943
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.345424    0.165505    0.403443    0.335581    0.158875    0.412899
# x    82.500000  117.500000  142.500000  142.500000  142.500000  142.500000
# y   323.333344  136.666672   83.333336   83.333336   83.333336   83.333336
# z  -224.387329   47.856884   13.697884 -197.822250  333.121063  274.824036
# c     0.343644    0.162780    0.403914    0.334252    0.158677    0.413231
#
#             12          13          14          15
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.648699    0.656663    0.656663    0.656663
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.650321    0.657114    0.657114    0.657114
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.650626    0.657111    0.657111    0.657111
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.650288    0.657203    0.657203    0.657203
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.650763    0.656758    0.656758    0.656758
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.651105    0.656524    0.656524    0.656524
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# z   381.338440  139.842453    9.675978   11.608283
# c     0.651312    0.656381    0.656381    0.656381
# x   402.500000  202.500000  382.500000  282.500000
# y   136.666672  163.333328  110.000000  190.000000
# ..         ...         ...         ...         ...
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.390462    0.158383    0.158383    0.158383
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.390483    0.158613    0.158613    0.158613
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.388805    0.157474    0.157474    0.157474
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.389389    0.155687    0.155687    0.155687
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.388347    0.154532    0.154532    0.154532
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.387891    0.153627    0.153627    0.153627
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.387464    0.152712    0.152712    0.152712
# x   142.500000  202.500000  142.500000   42.500000
# y   163.333328  163.333328   83.333336   83.333336
# z   221.901108   43.047230   20.561243   -1.811028
# c     0.386349    0.152501    0.152501    0.152501
#
# [476 rows x 16 columns]

# %%
xyzc_df.to_csv('address.csv')

# %%
c_temp.describe()
# Out:
#                  c
# count  1904.000000
# mean      0.262172
# std       0.193353
# min       0.012163
# 25%       0.127724
# 50%       0.170731
# 75%       0.365292
# max       0.791441
