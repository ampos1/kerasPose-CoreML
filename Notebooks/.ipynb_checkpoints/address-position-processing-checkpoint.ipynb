# %%
import pandas as pd
import numpy as np
import re

# %%
address_data = pd.read_csv("address2.txt")

# %%
df = pd.DataFrame(address_data)

# %%
df.rename(columns = {'<?xml version="1.0" encoding="UTF-8"?>': 'values'},inplace = True)

# %%
for i in range(0,df['values'].count()):
    if type(df['values'][i]) != str:
        val = df['values'][i]
        df['values'][i] = df['values'][i].to_string()

# %%
for i in range(0,df['values'].count()):
    if 'real' in df['values'][i]:
        temp = re.search('>(.*)</',df['values'][i])
        df['values'][i] = temp.group(1)

# %%
temp_df = df

# %%
check = ['a','e','i','o','u'] 

for i in range(0,temp_df['values'].count()):
    for vowel in check:
        if vowel in list(temp_df['values'][i]):
            temp_df.drop(index = i,inplace = True)
            break

# %%
res = temp_df
res = res.reset_index()
res.drop('index',axis=1,inplace=True)

# %%
x_temp = pd.DataFrame(np.zeros((4368,1)))
y_temp = pd.DataFrame(np.zeros((4368,1)))
z_temp = pd.DataFrame(np.zeros((4368,1)))
c_temp = pd.DataFrame(np.zeros((4368,1)))

# %%
def extract_x_values(data, x_vals):
    for i in range(0,int(data.count()),4):
        if(i == 0):
            x_vals[0][i] = data['values'][i]
        else:
            x_vals[0][(i/4)] = data['values'][i]
    return x_vals

# %%
def extract_y_values(data, y_vals):
    for i in range(1,int(data.count()),4):
        if(i == 1):
            y_vals[0][i-1] = data['values'][i]
        else:
            y_vals[0][(i-1)/4] = data['values'][i]
    return y_vals

# %%
def extract_z_values(data,z_vals):
    for i in range(2,int(data.count()),4):
        if(i == 2):
            z_vals[0][i-2] = data['values'][i]
        else:
            z_vals[0][(i-2)/4] = data['values'][i]
    return z_vals

# %%
def extract_c_values(data,c_vals):
    for i in range(3,int(data.count()),4):
        if(i == 3):
            c_vals[0][i-3] = data['values'][i]
        else:
            c_vals[0][int((i-3)/4)] = data['values'][i]
    return c_vals

# %%
x_temp = extract_x_values(res,x_temp)
y_temp = extract_y_values(res,y_temp)
z_temp = extract_z_values(res,z_temp)
c_temp = extract_c_values(res,c_temp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-36207aa641ef> in <module>
# ----> 1 x_temp = extract_x_values(res,x_temp)
#       2 y_temp = extract_y_values(res,y_temp)
#       3 z_temp = extract_z_values(res,z_temp)
#       4 c_temp = extract_c_values(res,c_temp)
#
# <ipython-input-14-6cccc99bb4fb> in extract_x_values(data, x_vals)
#       2     for i in range(0,int(data.count()),4):
#       3         if(i == 0):
# ----> 4             x_vals[0][i] = data['values'][i]
#       5         else:
#       6             x_vals[0][(i/4)] = data['values'][i]
#
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.virtualenvs/COGS108/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %%
x_temp.rename(columns={0:'x'},inplace=True)
y_temp.rename(columns={0:'y'},inplace=True)
z_temp.rename(columns={0:'z'},inplace=True)
c_temp.rename(columns={0:'c'},inplace=True)

# %%
xyz_df = pd.concat([x_temp,y_temp,z_temp,c_temp],axis=1)

# %%
def restructure(data):
    organized_df = pd.DataFrame()
    for i in range(0,273):
        lower_bound = 0
        upper_bound = 15
        curr_lower = lower_bound + (i*16)
        curr_upper = upper_bound + (i*16)
        
        df_splice = data.loc[curr_lower:curr_upper,:]
        df_splice.reset_index(inplace=True,drop=True)
        df_splice = df_splice.transpose()
        organized_df = pd.concat([organized_df,df_splice])
    
    return organized_df

# %%
xyz_df = restructure(xyz_df)

# %%
xyz_df.to_csv('address_data_csv')

# %%
xyz_df
# Out:
#             0           1           2           3           4           5   \
# x   192.500000  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.207444  -18.959591 -232.427444  -74.766479    0.064400   22.756737
# c     0.676898    0.000000    0.000000    0.000000    0.000000    0.000000
# x   192.500000  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.207444  -18.959591 -232.427444  -74.766479    0.064400   22.756737
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   195.833328  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.160796  -19.282440 -233.407928  -76.107880    0.497321   23.278999
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   195.000000  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.172460  -19.201668 -233.162720  -75.772598    0.388987   23.148170
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   194.500000  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.179462  -19.153305 -233.015488  -75.570694    0.324110   23.070229
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   194.166672  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.184124  -19.121017 -232.917282  -75.436508    0.280869   23.017799
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   193.928574  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# z    -4.187454  -19.098000 -232.847366  -75.340897    0.249997   22.980232
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   193.750000  122.500000  142.500000  122.500000  162.500000  202.500000
# y   136.666672  163.333328  243.333328  323.333344  190.000000  243.333328
# ..         ...         ...         ...         ...         ...         ...
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
#             6           7           8           9           10          11  \
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   122.886002   45.729679  -49.129887 -180.789322  338.932281  213.033035
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   122.886002   45.729679  -49.129887 -180.789322  338.932281  213.033035
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   123.850754   45.958649  -49.314289 -181.055740  339.483002  212.893204
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   123.609573   45.901417  -49.268375 -180.989090  339.345520  212.927902
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   123.464386   45.867081  -49.240559 -180.949249  339.262970  212.949051
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   123.367538   45.844151  -49.222107 -180.922592  339.207764  212.962997
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# z   123.299469   45.827778  -49.209099 -180.903641  339.168243  212.972809
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x   182.500000  172.500000  202.500000  202.500000  242.500000  222.500000
# y   296.666656  150.000000  123.333336  110.000000   83.333336  136.666672
# ..         ...         ...         ...         ...         ...         ...
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
#             12          13          14          15
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.547241  133.512527  -28.966345  -46.923943
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.547241  133.512527  -28.966345  -46.923943
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.526291  133.499435  -29.003675  -45.266533
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.531525  133.502426  -28.994417  -45.681129
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.534973  133.504959  -28.988760  -45.929634
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.536652  133.505539  -28.985094  -46.095772
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  182.500000
# y   190.000000  243.333328  110.000000  216.666672
# z   184.538055  133.506393  -28.982523  -46.213631
# c     0.000000    0.000000    0.000000    0.000000
# x   202.500000  222.500000  182.500000  177.500000
# y   190.000000  243.333328  110.000000  206.666672
# ..         ...         ...         ...         ...
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
# x     0.000000    0.000000    0.000000    0.000000
# y     0.000000    0.000000    0.000000    0.000000
# z     0.000000    0.000000    0.000000    0.000000
# c     0.000000    0.000000    0.000000    0.000000
#
# [1092 rows x 16 columns]
